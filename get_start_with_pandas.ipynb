# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
df = pd.read_csv('housing.csv')  
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.plot()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: >

# %%
df.plot(kind = "bar")
# Out:
# <Axes: >

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df.plot.barh()
# Out:
# <Axes: >

# %%
df.plot.bar(stacked = True)
# Out:
# <Axes: >

# %%
df.plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind = "area", stacked = True)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
x = [10,303,58,6,79,69]
y = [2,4,5,8,9,23]
plt.plot(x,y)

# %%
x = [10,20,30,40,50]
y = [1,2,3,4,5]
plt.plot(x,y)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
x = df['day']
y = df['total_bill']
plt.plot(x,y)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 244 artists>

# %%
plt.hist(x)
# Out:
# (array([76.,  0.,  0., 87.,  0.,  0., 62.,  0.,  0., 19.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import seaborn as sn

# %%
print(sn.__version__)
# Out:
# 0.13.2

# %%
sn.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sn.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df = sn.load_dataset("penguins")
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
#to load/import built in datasets
tips = sn.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sn.histplot(data = tips, x = "total_bill")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sn.scatterplot(x = "total_bill", y = "tip", data = tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
import matplotlib.pyplot as plt
sn.scatterplot(x ="total_bill", y = "tip", hue = "sex", size = "size", data = tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sn.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
fmri = sn.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sn.lineplot(x = "timepoint", y = "signal", data = fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
df = sn.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sn.barplot(x = "class", y = "fare", hue = "sex", data = df)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
df = sn.load_dataset("iris")
sn.histplot(x = "sepal_length", data = df)
#df.head()
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
import pandas as pd 
import seaborn as sb
df = pd.read_csv("employees.csv")
df.head()
# Out:
#   First Name  Gender       Department  Bonus % Senior   Salary  Age
# 0    Douglas    Male        Marketing    6.945    True   97308   33
# 1     Thomas    Male              NaN    4.170    True   61933   28
# 2      Maria  Female          Finance   11.858   False  130590   45
# 3      Jerry    Male          Finance    9.340    True  138705   32
# 4      Larry    Male  Client Services    1.389    True  101004   21

# %%
df.isnull().sum()
# Out:
# First Name    4
# Gender        6
# Department    4
# Bonus %       0
# Senior        5
# Salary        0
# Age           0
# dtype: int64

# %%
sb.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sb.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# How fill mising values?

# %%
df['column_name'].fillna(df['column_name'].mean(),inplace = True) # how to fill a verage value to the column

# %%
df['age'] = df['age'].fillna(df['age'].mean())

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.head(6)
# Out:
#    survived  pclass     sex        age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.000000      1      0   7.2500        S  Third
# 1         1       1  female  38.000000      1      0  71.2833        C  First
# 2         1       3  female  26.000000      0      0   7.9250        S  Third
# 3         1       1  female  35.000000      1      0  53.1000        S  First
# 4         0       3    male  35.000000      0      0   8.0500        S  Third
# 5         0       3    male  29.699118      0      0   8.4583        Q  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True

# %%
#To give specific value for the  missed column
df['column name'].fillna ("specific value", inplace = True)

# %%
df['age'] = df['age'].fillna('unknown')

# %%
df.head(10)
# Out:
#    survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0         0       3    male  22.000000      1      0   7.2500        S
# 1         1       1  female  38.000000      1      0  71.2833        C
# 2         1       3  female  26.000000      0      0   7.9250        S
# 3         1       1  female  35.000000      1      0  53.1000        S
# 4         0       3    male  35.000000      0      0   8.0500        S
# 5         0       3    male  29.699118      0      0   8.4583        Q
# 6         0       1    male  54.000000      0      0  51.8625        S
# 7         0       3    male   2.000000      3      1  21.0750        S
# 8         1       3  female  27.000000      0      2  11.1333        S
# 9         1       2  female  14.000000      1      0  30.0708        C
#
#     class    who  adult_male deck  embark_town alive  alone
# 0   Third    man        True  NaN  Southampton    no  False
# 1   First  woman       False    C    Cherbourg   yes  False
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
 df = sb.load_dataset("planets")
df.head(20)
# Out:
#              method  number  orbital_period    mass  distance  year
# 0   Radial Velocity       1      269.300000   7.100     77.40  2006
# 1   Radial Velocity       1      874.774000   2.210     56.95  2008
# 2   Radial Velocity       1      763.000000   2.600     19.84  2011
# 3   Radial Velocity       1      326.030000  19.400    110.62  2007
# 4   Radial Velocity       1      516.220000  10.500    119.47  2009
# 5   Radial Velocity       1      185.840000   4.800     76.39  2008
# 6   Radial Velocity       1     1773.400000   4.640     18.15  2002
# 7   Radial Velocity       1      798.500000     NaN     21.41  1996
# 8   Radial Velocity       1      993.300000  10.300     73.10  2008
# 9   Radial Velocity       2      452.800000   1.990     74.79  2010
# 10  Radial Velocity       2      883.000000   0.860     74.79  2010
# 11  Radial Velocity       1      335.100000   9.880     39.43  2009
# 12  Radial Velocity       1      479.100000   3.880     97.28  2008
# ...

# %%
df.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
df = df.dropna()
df.head(10)
# Out:
#              method  number  orbital_period   mass  distance  year
# 0   Radial Velocity       1         269.300   7.10     77.40  2006
# 1   Radial Velocity       1         874.774   2.21     56.95  2008
# 2   Radial Velocity       1         763.000   2.60     19.84  2011
# 3   Radial Velocity       1         326.030  19.40    110.62  2007
# 4   Radial Velocity       1         516.220  10.50    119.47  2009
# 5   Radial Velocity       1         185.840   4.80     76.39  2008
# 6   Radial Velocity       1        1773.400   4.64     18.15  2002
# 8   Radial Velocity       1         993.300  10.30     73.10  2008
# 9   Radial Velocity       2         452.800   1.99     74.79  2010
# 10  Radial Velocity       2         883.000   0.86     74.79  2010

# %%
df.shape
# Out:
# (498, 6)

# %%
sb.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sb.load_dataset('planets')
df.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
df.shape
# Out:
# (1035, 6)

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df = sb.load_dataset('planets')
df.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
df = df.dropna(axis = 1)

# %%
df.head()
# Out:
#             method  number  year
# 0  Radial Velocity       1  2006
# 1  Radial Velocity       1  2008
# 2  Radial Velocity       1  2011
# 3  Radial Velocity       1  2007
# 4  Radial Velocity       1  2009

# %%
df = sb.load_dataset( 'brain_networks')
df.isnull().sum()
# Out:
# network    1
# 1          1
# 1.1        1
# 2          1
# 2.1        1
#           ..
# 17.2       1
# 17.3       1
# 17.4       1
# 17.5       1
# 17.6       1
# Length: 63, dtype: int64

# %%
import pandas as pd 
import seaborn as sb
df = pd.read_csv("employees.csv")
df.head(15)
# Out:
#    First Name  Gender            Department  Bonus % Senior   Salary  Age
# 0     Douglas    Male             Marketing    6.945    True   97308   33
# 1      Thomas    Male                   NaN    4.170    True   61933   28
# 2       Maria  Female               Finance   11.858   False  130590   45
# 3       Jerry    Male               Finance    9.340    True  138705   32
# 4       Larry    Male       Client Services    1.389    True  101004   21
# 5      Dennis    Male                 Legal   10.125   False  115163   27
# 6        Ruby  Female               Product   10.012    True   65476   37
# 7         NaN  Female               Finance   11.598     NaN   45906   44
# 8      Angela  Female           Engineering   18.523    True   95570   34
# 9     Frances  Female  Business Development    7.524    True  139852   35
# 10     Louise  Female                   NaN   15.132    True   63241   31
# 11      Julie  Female                 Legal   12.637    True  102508   21
# ...

# %%
df.isnull().sum()
# Out:
# First Name    4
# Gender        6
# Department    4
# Bonus %       0
# Senior        5
# Salary        0
# Age           0
# dtype: int64

# %%
df["First Name"] = df["First Name"].fillna("Nema")

# %%
df.head(10)
# Out:
#   First Name  Gender            Department  Bonus % Senior   Salary  Age
# 0    Douglas    Male             Marketing    6.945    True   97308   33
# 1     Thomas    Male                   NaN    4.170    True   61933   28
# 2      Maria  Female               Finance   11.858   False  130590   45
# 3      Jerry    Male               Finance    9.340    True  138705   32
# 4      Larry    Male       Client Services    1.389    True  101004   21
# 5     Dennis    Male                 Legal   10.125   False  115163   27
# 6       Ruby  Female               Product   10.012    True   65476   37
# 7       Nema  Female               Finance   11.598     NaN   45906   44
# 8     Angela  Female           Engineering   18.523    True   95570   34
# 9    Frances  Female  Business Development    7.524    True  139852   35

# %%
df["Department"] = df["Department"].fillna("sales")

# %%
df.head(10)
# Out:
#   First Name  Gender            Department  Bonus % Senior   Salary  Age
# 0    Douglas    Male             Marketing    6.945    True   97308   33
# 1     Thomas    Male                 sales    4.170    True   61933   28
# 2      Maria  Female               Finance   11.858   False  130590   45
# 3      Jerry    Male               Finance    9.340    True  138705   32
# 4      Larry    Male       Client Services    1.389    True  101004   21
# 5     Dennis    Male                 Legal   10.125   False  115163   27
# 6       Ruby  Female               Product   10.012    True   65476   37
# 7       Nema  Female               Finance   11.598     NaN   45906   44
# 8     Angela  Female           Engineering   18.523    True   95570   34
# 9    Frances  Female  Business Development    7.524    True  139852   35

# %%
# Handeling Duplicated data

# %%
import pandas as pd
import numpy as np
import seaborn as sn
sn.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sn.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.head(15)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %%
df.duplicated().sum()
# Out:
# 107

# %%
df.shape
# Out:
# (891, 15)

# %%
pure = df.drop_duplicates()

# %%
pure.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
pure.shape
# Out:
# (784, 15)

# %%
107 +784
# Out:
# 891

# %%
pure.duplicated().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 107

# %%
pure.drop_duplicates(subset = "deck")
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0          0       3    male  22.0      1      0    7.2500        S   Third
# 1          1       1  female  38.0      1      0   71.2833        C   First
# 6          0       1    male  54.0      0      0   51.8625        S   First
# 10         1       3  female   4.0      1      1   16.7000        S   Third
# 21         1       2    male  34.0      0      0   13.0000        S  Second
# 23         1       1    male  28.0      0      0   35.5000        S   First
# 31         1       1  female   NaN      1      0  146.5208        C   First
# 66         1       2  female  29.0      0      0   10.5000        S  Second
#
#       who  adult_male deck  embark_town alive  alone
# 0     man        True  NaN  Southampton    no  False
# 1   woman       False    C    Cherbourg   yes  False
# 6     man        True    E  Southampton    no   True
# 10  child       False    G  Southampton   yes  False
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
#How to explort/save the cleaned dataset?
path = r'C:\Users\Cash America\OneDrive\Desktop\Data Analysis\new_titanic_file.csv'
pure.to_csv(path,index = False)

# %%
new_df = pd.read_csv(path)

# %%
new_df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.duplicated().sum()
# Out:
# 107

# %%
new_df.duplicated().sum()
# Out:
# 0

# %%
sn.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# Data type cdonversation

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df['fare'] = df['fare'].astype(int)
#df['column_name'].astype(desired data type)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch  fare embarked  class    who  \
# 0         0       3    male  22.0      1      0     7        S  Third    man
# 1         1       1  female  38.0      1      0    71        C  First  woman
# 2         1       3  female  26.0      0      0     7        S  Third  woman
# 3         1       1  female  35.0      1      0    53        S  First  woman
# 4         0       3    male  35.0      0      0     8        S  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %%
df['age'] = df['age'].fillna(df['age'].mean())

# %%
df.head(10)
# Out:
#    survived  pclass     sex        age  sibsp  parch  fare embarked   class  \
# 0         0       3    male  22.000000      1      0     7        S   Third
# 1         1       1  female  38.000000      1      0    71        C   First
# 2         1       3  female  26.000000      0      0     7        S   Third
# 3         1       1  female  35.000000      1      0    53        S   First
# 4         0       3    male  35.000000      0      0     8        S   Third
# 5         0       3    male  29.699118      0      0     8        Q   Third
# 6         0       1    male  54.000000      0      0    51        S   First
# 7         0       3    male   2.000000      3      1    21        S   Third
# 8         1       3  female  27.000000      0      2    11        S   Third
# 9         1       2  female  14.000000      1      0    30        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
df['age'] = df['age'].fillna(df['age'].mean()).astype(int)

# %%
df.head(10)
# Out:
#    survived  pclass     sex  age  sibsp  parch  fare embarked   class    who  \
# 0         0       3    male   22      1      0     7        S   Third    man
# 1         1       1  female   38      1      0    71        C   First  woman
# 2         1       3  female   26      0      0     7        S   Third  woman
# 3         1       1  female   35      1      0    53        S   First  woman
# 4         0       3    male   35      0      0     8        S   Third    man
# 5         0       3    male   29      0      0     8        Q   Third    man
# 6         0       1    male   54      0      0    51        S   First    man
# 7         0       3    male    2      3      1    21        S   Third  child
# 8         1       3  female   27      0      2    11        S   Third  woman
# 9         1       2  female   14      1      0    30        C  Second  child
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# ...

# %%
df['age'] = df['age'].astype(float)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch  fare embarked  class    who  \
# 0         0       3    male  22.0      1      0     7        S  Third    man
# 1         1       1  female  38.0      1      0    71        C  First  woman
# 2         1       3  female  26.0      0      0     7        S  Third  woman
# 3         1       1  female  35.0      1      0    53        S  First  woman
# 4         0       3    male  35.0      0      0     8        S  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %%
df['alive'] = df['alive'].map({'yes': True, 'no':False})
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch  fare embarked  class    who  \
# 0         0       3    male  22.0      1      0     7        S  Third    man
# 1         1       1  female  38.0      1      0    71        C  First  woman
# 2         1       3  female  26.0      0      0     7        S  Third  woman
# 3         1       1  female  35.0      1      0    53        S  First  woman
# 4         0       3    male  35.0      0      0     8        S  Third    man
#
#    adult_male deck  embark_town  alive  alone
# 0        True  NaN  Southampton  False  False
# 1       False    C    Cherbourg   True  False
# 2       False  NaN  Southampton   True   True
# 3       False    C  Southampton   True  False
# 4        True  NaN  Southampton  False   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    int32
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    bool
#  14  alone        891 non-null    bool
# dtypes: bool(3), category(2), float64(1), int32(1), int64(4), object(4)
# memory usage: 71.1+ KB

# %%
#outlier handeling
